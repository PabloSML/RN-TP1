# %% [markdown]
# # Trabajo Práctico Nro 1 - Redes Neuronales, ITBA 2023
# Autor: Pablo Smolkin
#
# Legajo 59523
# ***

# %% [markdown]
# ### Imports

# %%
from mlp_helper import *

# %% [markdown]
# ### Load Dataset

# %%
x_data, x_test, y_data, class_names = load_fmnist_data()
# Out:
# x data Shape: (60000, 28, 28)
# x data Shape: (10000, 28, 28)
# y data Shape: (60000,)

# %% [markdown]
# ### 2. **Modelos:**
# Entrenar un modelo de clasificación en las 10 clases de Fashion MNIST. MLP. En el caso que corresponda probar y comparar: distintas funciones de activación, distintos optimizadores, distintas funciones de costo, distintos tamaños de red (cantidad de capas y tamaño de cada capa), learning rate, batch_size, dropout rates, batch_normalization (si/no), inicializaciones de pesos (glorot_uniform, glorot_normal, normal(0,1), normal(0,0.001)).
#
# Métricas a reportar para cada entrenamiento de interés: Accuracy como métrica principal.
# Como métricas secundarias: área bajo la curva ROC, F1-score, Precisión y
# Recall. Enunciar para el F1-score y el área bajo la curva ROC cómo se calculan los
# promedios macro y micro. Justificar cuál de los dos es el que corresponde reportar en este
# problema.
#
# Para un buen modelo obtenido en el punto anterior (así si lo mejoran no tienen que repetir
# este punto), variar los hiperparámetros de a uno y graficar:
#
# * Accuracy vs [LEARNING_RATE, BATCH_SIZE, OPTIMIZADORES, ACTIVACIONES, DROPOUT_RATE, BATCH_NORMALIZATION, INICIALIZACIONES DE PESOS]
#
# * Iteraciones de entrenamiento vs [LEARNING_RATE, BATCH_SIZE, OPTIMIZADORES, ACTIVACIONES, DROPOUT_RATE, BATCH_NORMALIZATION, INICIALIZACIONES DE PESOS]
#
# Intente justificar los gráficos obtenidos. Valores mínimos esperados para cada modelo: SoftmaxReg: .70, MLP: .83

# %%
# Loading TensorBoard for learning logging
# %load_ext tensorboard

# %%
best_model = {"id": None, "val_acc": 0.0}

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.952825  0.889350
# auc        0.998703  0.991362
# f1         0.956390  0.887978
# loss       0.144002  0.334289
# precision  0.960969  0.900979
# recall     0.944200  0.878950
# Model ID: 20230521-230529

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_units=64,
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.958650  0.883850
# auc        0.999003  0.988447
# f1         0.961155  0.882816
# loss       0.126460  0.380891
# precision  0.965364  0.892801
# recall     0.951825  0.876150
# Model ID: 20230521-230710

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_units=256,
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.972175  0.893250
# auc        0.999523  0.989944
# f1         0.977568  0.892288
# loss       0.092886  0.347528
# precision  0.976407  0.901712
# recall     0.967400  0.884850
# Model ID: 20230521-230929

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_units=512,
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.988875  0.895600
# auc        0.999902  0.987254
# f1         0.991205  0.894838
# loss       0.044108  0.385697
# precision  0.990200  0.901037
# recall     0.987700  0.890900
# Model ID: 20230521-231140

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='SGD',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.852900  0.838650
# auc        0.989125  0.986984
# f1         0.852413  0.837096
# loss       0.420166  0.454385
# precision  0.890405  0.877290
# recall     0.814075  0.802150
# Model ID: 20230521-231651

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='RMSprop',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.946925  0.888500
# auc        0.998405  0.991438
# f1         0.953388  0.887387
# loss       0.158716  0.326677
# precision  0.955647  0.901119
# recall     0.936725  0.878050
# Model ID: 20230521-232036

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='mean_squared_error',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.958575  0.889850
# auc        0.994968  0.989845
# f1         0.961319  0.889187
# loss       0.007432  0.016517
# precision  0.966892  0.902240
# recall     0.952775  0.880000
# Model ID: 20230521-232207

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='mean_absolute_error',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.935650  0.882200
# auc        0.973219  0.967132
# f1         0.937702  0.881226
# loss       0.014016  0.024360
# precision  0.936316  0.884147
# recall     0.935450  0.881450
# Model ID: 20230521-232415

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.951675  0.885250
# auc        0.998349  0.984894
# f1         0.963527  0.884626
# loss       0.130102  0.460031
# precision  0.955539  0.891438
# recall     0.948325  0.881900
# Model ID: 20230521-232653

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0005,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.953150  0.887050
# auc        0.998604  0.987560
# f1         0.961077  0.886155
# loss       0.130264  0.398561
# precision  0.957888  0.894432
# recall     0.948525  0.881150
# Model ID: 20230521-232808

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=64,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.954500  0.891800
# auc        0.998781  0.991111
# f1         0.959636  0.890989
# loss       0.138123  0.329906
# precision  0.963447  0.904146
# recall     0.946225  0.881000
# Model ID: 20230521-232918

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=128,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.951175  0.891500
# auc        0.998565  0.991668
# f1         0.953996  0.890712
# loss       0.153490  0.326562
# precision  0.960230  0.904911
# recall     0.940425  0.879800
# Model ID: 20230521-233037

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=16,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.951000  0.889400
# auc        0.998619  0.990454
# f1         0.957849  0.888309
# loss       0.143918  0.342743
# precision  0.959008  0.900286
# recall     0.942225  0.881200
# Model ID: 20230521-233128

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='glorot_uniform',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.963275  0.889050
# auc        0.999169  0.990107
# f1         0.967907  0.888276
# loss       0.116380  0.346803
# precision  0.969233  0.899913
# recall     0.956100  0.881600
# Model ID: 20230521-233433

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='random_normal',
    weight_initializer_stddev=1,
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
# d:\VSCodeRepos\RN-TP1\venv\lib\site-packages\keras\initializers\initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
#               train       val
# accuracy   0.905150  0.818900
# auc        0.964571  0.910056
# f1         0.909912  0.817668
# loss       1.999686  8.309154
# precision  0.905654  0.818932
# recall     0.904975  0.818850
# Model ID: 20230521-233653

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    weight_initializer='random_normal',
    weight_initializer_stddev=0.001,
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
# d:\VSCodeRepos\RN-TP1\venv\lib\site-packages\keras\initializers\initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
#               train       val
# accuracy   0.958600  0.890600
# auc        0.998893  0.990144
# f1         0.960004  0.889827
# loss       0.126165  0.346694
# precision  0.965574  0.899272
# recall     0.951525  0.882950
# Model ID: 20230521-234150

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 256, 128],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.949300  0.892250
# auc        0.998591  0.990746
# f1         0.958315  0.890084
# loss       0.142344  0.333985
# precision  0.956307  0.902301
# recall     0.942225  0.884300
# Model ID: 20230527-140137

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[256, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.982650  0.888900
# auc        0.999738  0.984141
# f1         0.985429  0.887650
# loss       0.056906  0.435267
# precision  0.984839  0.894157
# recall     0.980875  0.885350
# Model ID: 20230527-140520

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=2,
    hidden_units=[512, 256],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.977425  0.895250
# auc        0.999706  0.987931
# f1         0.984726  0.894112
# loss       0.069433  0.373138
# precision  0.979218  0.902386
# recall     0.975375  0.890700
# Model ID: 20230527-140730

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 32, 32],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.977100  0.892350
# auc        0.999604  0.987344
# f1         0.982525  0.891408
# loss       0.075031  0.383258
# precision  0.979415  0.898659
# recall     0.974200  0.888100
# Model ID: 20230527-141137

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=1,
    hidden_units=[512],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=True,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.969100  0.892400
# auc        0.999417  0.987422
# f1         0.980116  0.891677
# loss       0.091208  0.445057
# precision  0.972247  0.899600
# recall     0.966000  0.887500
# Model ID: 20230527-143928

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=2,
    hidden_units=[512, 512],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=True,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.961825  0.893000
# auc        0.999248  0.988442
# f1         0.978145  0.891861
# loss       0.103640  0.401792
# precision  0.966143  0.900522
# recall     0.958100  0.888500
# Model ID: 20230527-144502

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=True,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.957250  0.890200
# auc        0.999077  0.987233
# f1         0.977457  0.889424
# loss       0.116574  0.395111
# precision  0.961762  0.897235
# recall     0.953250  0.885750
# Model ID: 20230527-145038

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=1,
    hidden_units=[512],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=False,
    dropout_rate=0.1,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.987125  0.897700
# auc        0.999862  0.987214
# f1         0.994486  0.896770
# loss       0.046554  0.395128
# precision  0.988392  0.902919
# recall     0.985575  0.893800
# Model ID: 20230527-164950

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=1,
    hidden_units=[512],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=False,
    dropout_rate=0.3,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.979875  0.900150
# auc        0.999743  0.987080
# f1         0.992925  0.899459
# loss       0.060542  0.395815
# precision  0.982117  0.906094
# recall     0.977575  0.897350
# Model ID: 20230527-165553

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=1,
    hidden_units=[512],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=False,
    dropout_rate=0.01,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.975475  0.893700
# auc        0.999637  0.989338
# f1         0.981723  0.892854
# loss       0.081053  0.354972
# precision  0.978964  0.902882
# recall     0.971450  0.888300
# Model ID: 20230527-170324

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=1,
    hidden_units=[512, 128],
    weight_initializer='glorot_normal',
    optimizer='Adam',
    learning_rate=0.0001,
    batch_normalization=False,
    dropout_rate=0.1,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=32,
    max_epochs=100,
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#               train       val
# accuracy   0.964425  0.897900
# auc        0.999260  0.991216
# f1         0.976801  0.897359
# loss       0.108607  0.326680
# precision  0.969270  0.906136
# recall     0.958875  0.890550
# Model ID: 20230527-170729

# %% [markdown]
# Best model this far: 20230527-165553 with validation accuracy: 0.9001500010490417

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Nadam',
    learning_rate=0.001,
    batch_normalization=True,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=64,
    max_epochs=100,
    reduce_lr_config = {
            'monitor': 'val_accuracy',
            'factor': 0.2,
            'patience': 5,
            'min_lr': 0.00005
    },
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True,
        'min_delta': 0.007
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#                  train         val
# accuracy      0.910250    0.885800
# auc           0.995920    0.991791
# f1            0.931386    0.884925
# iterations  384.000000  384.000000
# loss          0.239757    0.324969
# lr            0.001000         NaN
# precision     0.922765    0.900900
# recall        0.899050    0.875450
# Model ID: 20230531-102503

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Nadam',
    learning_rate=0.001,
    batch_normalization=True,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=64,
    max_epochs=100,
    reduce_lr_config = {
            'monitor': 'val_accuracy',
            'factor': 0.2,
            'patience': 5,
            'min_lr': 0.00005
    },
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True,
        'min_delta': 0.003
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#                  train         val
# accuracy      0.948125    0.899500
# auc           0.998620    0.992028
# f1            0.962002    0.898760
# iterations  640.000000  640.000000
# loss          0.141647    0.304453
# lr            0.000200         NaN
# precision     0.954222    0.908786
# recall        0.942175    0.893200
# Model ID: 20230531-103413

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Nadam',
    learning_rate=0.001,
    activation='relu',
    batch_normalization=True,
    dropout_rate=0.3,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=64,
    max_epochs=100,
    reduce_lr_config = {
            'monitor': 'val_accuracy',
            'factor': 0.2,
            'patience': 5,
            'min_lr': 0.00005
    },
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True,
        'min_delta': 0.005
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#                  train         val
# accuracy      0.888050    0.889000
# auc           0.993140    0.992614
# f1            0.920006    0.887139
# iterations  896.000000  896.000000
# loss          0.311927    0.308102
# lr            0.001000         NaN
# precision     0.907761    0.904681
# recall        0.869975    0.876500
# Model ID: 20230531-103612

# %%
model, x_train, x_valid, y_train, y_valid = create_fmnist_model(
    x_data,
    y_data,
    metrics=['accuracy','AUC','Precision','Recall'],
    loss='categorical_crossentropy',
    hidden_layers=3,
    hidden_units=[512, 64, 64],
    weight_initializer='glorot_normal',
    optimizer='Nadam',
    learning_rate=0.001,
    activation='elu',
    batch_normalization=True,
    dropout_rate=0.3,
    train_valid_proportion=1/3,
    random_state_seed=10,
    verbose=False
)

history, metrics_df, id = run_model(
    model=model,
    x_train=x_train,
    x_valid=x_valid,
    y_train=y_train,
    y_valid=y_valid,
    batch_size=64,
    max_epochs=100,
    reduce_lr_config = {
            'monitor': 'val_accuracy',
            'factor': 0.2,
            'patience': 5,
            'min_lr': 0.00005
    },
    es_config = {
        'monitor': 'val_accuracy',
        'patience': 10,
        'mode': 'max',
        'restore_best_weights': True,
        'min_delta': 0.003
    },
    show_metrics=True,
    verbose=False
)

print(f'Model ID: {id}')

# Saving the model
model.save(f'models/fmnist_mlp_coarse/{id}.h5')

# See if highscore
if best_model["val_acc"] < metrics_df['val']['accuracy']:
    best_model["id"] = id
    best_model["val_acc"] = metrics_df['val']['accuracy']
# Out:
#                   train          val
# accuracy       0.929725     0.903050
# auc            0.997023     0.992666
# f1             0.954611     0.902439
# iterations  1472.000000  1472.000000
# loss           0.192251     0.291165
# lr             0.000200          NaN
# precision      0.938320     0.911821
# recall         0.921125     0.897050
# Model ID: 20230531-103839

# %%
print(f'Best model: {best_model["id"]} with validation accuracy: {best_model["val_acc"]}')
# Out:
# Best model: 20230531-103839 with validation accuracy: 0.9030500054359436
